# %%
import os
import pandas as pd

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)

# %%
df = pd.read_csv('data/data.csv')
df.head(20)
# Out:
#     Unnamed: 0                                   _id  \
# 0            0  9f84e3cf-28a7-4f80-a7e2-f8c646b61a42
# 1            1  aac20a4b-ddee-4f6f-9790-8e87d26795aa
# 2            2  fa13835e-f367-4488-84b0-c7e75b4dd042
# 3            3  c5e21907-4aec-400e-963f-befceb0ef33c
# 4            4  7511b715-a1a6-40ff-b9c3-4d9037fe4607
# 5            5  97d5ade8-a16b-4738-bf90-c318b0b3ef19
# 6            6  6e2c9b11-53e5-4b78-bb61-1048cd0f50b4
# 7            7  261a183e-6fa8-4255-aa7c-6e5fb1d6743d
# 8            8  2adaaa25-19b5-4255-92be-56c2adfcc7b7
# 9            9  03c745d3-38fa-4db6-b2df-0feda7e5bc71
# 10          10  3f13188f-9e18-479b-9ab3-29477afbefee
# 11          11  7a72ab54-880e-47cc-857a-021e538bf52b
# 12          12  f2f4ce56-e4a2-4f16-87fb-8744123d278a
# 13          13  a8d938c6-64e7-4eb9-a6e7-ed6a98a6f77f
# 14          14  79cd8440-dd71-40c6-8beb-3f504ee409b7
# 15          15  1dd9e7f3-5b08-4fed-be30-798de0896c9a
# 16          16  e488baa9-da4c-4502-965a-118cf560d615
# ...

# %%
df[['_id', '_bag_id', '_timestamp', '_topic', '_type', 'header__stamp__sec', 'header__stamp__nanosec', 'header__frame_id', 'nov_header__message_name', 'nov_header__message_id', 'nov_header__message_type', 'nov_header__sequence_number', 'nov_header__time_status', 'nov_header__gps_week_number', 'nov_header__gps_week_milliseconds', 'nov_header__receiver_status', 'nov_header__idle_time', 'latitude', 'longitude', 'height', 'north_velocity', 'east_velocity', 'up_velocity', 'roll', 'pitch', 'azimuth', 'pos_type__type']]
# Out:
#                                        _id  \
# 0     9f84e3cf-28a7-4f80-a7e2-f8c646b61a42
# 1     aac20a4b-ddee-4f6f-9790-8e87d26795aa
# 2     fa13835e-f367-4488-84b0-c7e75b4dd042
# 3     c5e21907-4aec-400e-963f-befceb0ef33c
# 4     7511b715-a1a6-40ff-b9c3-4d9037fe4607
# ...                                    ...
# 8122  98c67b9b-7524-49c0-96c8-d56a8de43596
# 8123  ac53340c-f848-413a-9a80-de8c25432160
# 8124  7e046752-3453-4d58-8853-5e1b666d19b0
# 8125  9558fc7f-68b1-45bc-bb20-2efd7f8682bc
# 8126  527c1b85-f7ac-4e6c-8613-e34b3e08c193
#
#                                    _bag_id           _timestamp  \
# 0     8941a4d9-2ec5-e763-1729-7aa4d329b06a  1699948939045476497
# 1     8941a4d9-2ec5-e763-1729-7aa4d329b06a  1699948940044314703
# 2     8941a4d9-2ec5-e763-1729-7aa4d329b06a  1699948941050300748
# 3     8941a4d9-2ec5-e763-1729-7aa4d329b06a  1699948942053861726
# 4     8941a4d9-2ec5-e763-1729-7aa4d329b06a  1699948943076547124
# ...

# %%
df[df['pos_type__type'] == 19]
# Out:
#       Unnamed: 0                                   _id  \
# 269          269  9ae11eab-e321-4004-893b-3c78cebbb2d2
# 272          272  ed3906f4-820f-4e7b-95f3-63d8c0543124
# 273          273  02218823-2662-496a-a19d-514b711be2bf
# 274          274  e9cc466e-d0ba-4eb0-b6d8-a5a372542376
# 275          275  211d4551-1b6a-4bf5-9fb7-4add7f69c259
# ...          ...                                   ...
# 8007        8007  f1ad2b3b-7fd9-4393-8a57-a39023bfa659
# 8008        8008  095cf1be-dfa8-4a2c-868c-66506b5c6e3d
# 8009        8009  df270e41-dc83-4c3c-9259-f5e085157f0f
# 8093        8093  6f9000e8-cf97-4d5f-9235-baccba135a65
# 8094        8094  6549398e-569c-40e8-95a2-fa7b0bcdb2a1
#
#                                    _bag_id           _timestamp  \
# 269   8941a4d9-2ec5-e763-1729-7aa4d329b06a  1699949208050798836
# 272   8941a4d9-2ec5-e763-1729-7aa4d329b06a  1699949211040502372
# 273   8941a4d9-2ec5-e763-1729-7aa4d329b06a  1699949212052020780
# ...

# %%
df[['latitude', 'longitude']]
# Out:
#        latitude  longitude
# 0     59.814623  30.316313
# 1     59.814673  30.316206
# 2     59.814724  30.316096
# 3     59.814778  30.315981
# 4     59.814835  30.315859
# ...         ...        ...
# 8122  59.774619  30.360762
# 8123  59.774619  30.360762
# 8124  59.774619  30.360762
# 8125  59.774619  30.360762
# 8126  59.774619  30.360762
#
# [8127 rows x 2 columns]
